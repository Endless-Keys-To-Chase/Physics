# %%
print('hello world')
# Out:
# hello world

# %%
i = 32
j = 4

print(i+j," ", i-j ," ", i*j,' ', i/j ," ",i//j, ' ',i%j," ", i**j," ")
# Out:
# 36   28   128   8.0   8   0   1048576

# %%
p = k = 2
print(p,k)
k = 3
print(p,k)
# Out:
# 2 2
# 2 3

# %%
import numpy as np
from matplotlib import pyplot as plt

Age_X = np.array([10,15,30,50,60])
Distance_Y = np.array([136,318,657,1079,1257])

slope, intercept = np.polyfit(Age_X,Distance_Y,1)
trendline_y = slope * Age_X + intercept

plt.scatter(Age_X,Distance_Y)
plt.xlabel("Age(in Ma)")
plt.ylabel("Distance(in Km)")
plt.title("Half Spreading Rate Estimation")
plt.plot(Age_X,trendline_y,label = "Distance " + "= " + "Age * " + str(f"{slope:.7f}") +" + "+ f"{intercept:.7f}", color = "r")
plt.legend()
plt.show()
slope = slope*0.2
print(slope)
# Out:
# 4.410531914893618

# %%
import numpy as np
from matplotlib import pyplot as plt
x = np.array([1,2,3,4,5])
y = np.array([2,5,3,8,7])
slope, intercept = np.polyfit(x,y,1)
print("slope " ,slope)
trendline = slope*x + intercept
plt.scatter(x,y)
plt.plot(trendline)
# Out:
# slope  1.2999999999999998

# %%
import numpy as np
import matplotlib.pyplot as plt

T1 = np.array([5,10,15,20,25])
K1 = np.array([np.pi,np.pi,np.pi,np.pi,np.pi])
K2 = np.array([np.pi*3,np.pi*3,np.pi*3,np.pi*3,np.pi*3])
T2a = np.array([25,35,45,55,65])
T2b = np.array([28.8,33.8,43.8,55.6,61.8])
T2c = np.array([28.2,36.7,46,54,64])
T2_a = np.array([105,110.5,136,149,164])
T2_b = np.array([95,100,114,125,135])
T2_c = np.array([87,106,124,136,148])
plt.scatter(K1,np.log(T2a/T1),color = 'red')
plt.scatter(K1,np.log(T2b/T1),color = 'blue')
plt.scatter(K1,np.log(T2c/T1),color = 'magenta')
plt.scatter(K2,np.log(T2_a/T1),color = 'red')
plt.scatter(K2,np.log(T2_b/T1),color = 'blue')
plt.scatter(K2,np.log(T2_c/T1),color = 'magenta')
TH = np.concatenate([K1,K1,K1,K2,K2,K2])
P2 = np.concatenate([T2a,T2b,T2c,T2_a,T2_b,T2_c])
P1 = np.concatenate([T1,T1,T1,T1,T1,T1])
slope , intercept= np.polyfit(TH,np.log(P2/P1),1)
trendline = slope*TH + intercept
plt.plot(TH,trendline, color ='green')
#Z = np.array([np.mean(np.log(T2a/T1)),np.mean(np.log(T2b/T1)),np.mean(np.log(T2c/T1)),np.mean(np.log(T2_a/T1)),np.mean(np.log(T2_b/T1)),np.mean(np.log(T2_c/T1))])
#Y = np.array([np.pi,np.pi,np.pi,np.pi*3,np.pi*3,np.pi*3])
#plt.scatter(Z,Y,color = 'red')
#slope , intercept= np.polyfit(Y,Z,1)
#trendline = slope*TH + intercept,plt.plot(TH,trendline, color ='blue')
plt.title("log(T2/T1) vs θ Scatter Plot with best fit Trendline")
plt.xlabel("θ (π = 3.14)")
plt.ylabel("log(T2/T1)")
plt.show()

# %%
eta = 1/TH*np.log(P2/P1)
print(eta)
plt.scatter(TH,eta)
plt.title("Friction coefficient")
plt.xlabel("θ (π = 3.14)")
plt.ylabel("friction coefficient")
plt.show()
# Out:
# [0.5123     0.39876684 0.34969915 0.32200257 0.30414874 0.55734071
#  0.38766188 0.34109566 0.32545624 0.28807921 0.5506392  0.41386386
#  0.35669526 0.31616186 0.2992136  0.32303386 0.25490579 0.23391582
#  0.21307813 0.1995793  0.31241468 0.24431187 0.21519321 0.19444293
#  0.17893249 0.3030809  0.25049439 0.22411471 0.20339181 0.18868736]

# %%
eta = 1/TH*np.log(P2/P1)
print(eta)
plt.scatter(P1,eta)
plt.title("Friction coefficient")
plt.xlabel("Weight(M1)")
plt.ylabel("friction coefficient")
plt.show()
# Out:
# [0.5123     0.39876684 0.34969915 0.32200257 0.30414874 0.55734071
#  0.38766188 0.34109566 0.32545624 0.28807921 0.5506392  0.41386386
#  0.35669526 0.31616186 0.2992136  0.32303386 0.25490579 0.23391582
#  0.21307813 0.1995793  0.31241468 0.24431187 0.21519321 0.19444293
#  0.17893249 0.3030809  0.25049439 0.22411471 0.20339181 0.18868736]

# %%
import numpy as np
import matplotlib.pyplot as plt

T1 = np.array([5,10,15,20,25])
K1 = np.array([np.pi,np.pi,np.pi,np.pi,np.pi])
K2 = np.array([np.pi*3,np.pi*3,np.pi*3,np.pi*3,np.pi*3])
T2a = np.array([25,35,45,55,65])
T2b = np.array([28.8,33.8,43.8,55.6,61.8])
T2c = np.array([28.2,36.7,46,54,64])
T2_a = np.array([105,110.5,136,149,164])
T2_b = np.array([95,100,114,125,135])
T2_c = np.array([87,106,124,136,148])
plt.scatter(K1,np.log(T2a/T1),color = 'red')
plt.scatter(K1,np.log(T2b/T1),color = 'blue')
plt.scatter(K1,np.log(T2c/T1),color = 'magenta')
plt.scatter(K2,np.log(T2_a/T1),color = 'red')
plt.scatter(K2,np.log(T2_b/T1),color = 'blue')
plt.scatter(K2,np.log(T2_c/T1),color = 'magenta')
TH = np.concatenate([K1,K1,K1,K2,K2,K2])
P2 = np.concatenate([T2a,T2b,T2c,T2_a,T2_b,T2_c])
P1 = np.concatenate([T1,T1,T1,T1,T1,T1])
slope , intercept= np.polyfit(TH,np.log(P2/P1),1)
trendline = slope*TH + intercept
plt.plot(TH,trendline, color ='green')
#Z = np.array([np.mean(np.log(T2a/T1)),np.mean(np.log(T2b/T1)),np.mean(np.log(T2c/T1)),np.mean(np.log(T2_a/T1)),np.mean(np.log(T2_b/T1)),np.mean(np.log(T2_c/T1))])
#Y = np.array([np.pi,np.pi,np.pi,np.pi*3,np.pi*3,np.pi*3])
#plt.scatter(Z,Y,color = 'red')
#slope , intercept= np.polyfit(Y,Z,1)
#trendline = slope*TH + intercept,plt.plot(TH,trendline, color ='blue')
plt.title("log(T2/T1) vs θ Scatter Plot with best fit Trendline")
plt.xlabel("θ (π = 3.14)")
plt.ylabel("log(T2/T1)")
plt.show()

# %%
import numpy as np
A1 = np.array([25,28.8,28.2])
A2 = np.array([35,33.8,36.7])
A3 = np.array([45,43.8,46])
A4 = np.array([55,55.6,54])
A5 = np.array([65,61.8,64])

A6 = np.array([105,95,87])
A7 = np.array([110.5,100,106])
A8 = np.array([136,114,124])
A9 = np.array([149,125,136])
A10 = np.array([164,135,148])

Std = np.array([np.std(A1),np.std(A2),np.std(A3),np.std(A4),np.std(A5),np.std(A6),np.std(A7),np.std(A8),np.std(A9),np.std(A10)])
Std_err = Std/np.sqrt(3)
print(Std)
print(Std_err)

del_u = (Std_err[:5]/np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)]))*(1/np.pi)
el_u = (Std_err[-5:]/np.array([np.mean(A6),np.mean(A7),np.mean(A8),np.mean(A9),np.mean(A10)]))*(1/(3*np.pi))
print(del_u)
print(el_u)
#print(Std_err[:5])
AP = np.concatenate([del_u,el_u])
print(np.mean(AP))
# Out:
# [ 1.66799947  1.18977122  0.8993825   0.65996633  1.33666251  7.36357401
#   4.30116263  8.99382504  9.80929265 11.86029792]
# [0.96301994 0.68691473 0.51925873 0.38103174 0.77172246 4.25136144
#  2.4832774  5.19258731 5.66339775 6.84754619]
# [0.01121483 0.00621759 0.00367845 0.00221056 0.00386237]
# [0.00471516 0.00249748 0.00441939 0.00439687 0.00487616]
# 0.004808885539777302

# %%
import numpy as np
A1 = np.array([25,28.8,28.2])
A2 = np.array([35,33.8,36.7])
A3 = np.array([45,43.8,46])
A4 = np.array([55,55.6,54])
A5 = np.array([65,61.8,64])

A6 = np.array([105,95,87])
A7 = np.array([110.5,100,106])
A8 = np.array([136,114,124])
A9 = np.array([149,125,136])
A10 = np.array([164,135,148])

Std = np.array([np.std(A1),np.std(A2),np.std(A3),np.std(A4),np.std(A5),np.std(A6),np.std(A7),np.std(A8),np.std(A9),np.std(A10)])
Std_err = Std/np.sqrt(3)
print(Std)
print(Std_err)

del_u = (Std_err[:5]/np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)]))*(1/np.pi)
el_u = (Std_err[-5:]/np.array([np.mean(A6),np.mean(A7),np.mean(A8),np.mean(A9),np.mean(A10)]))*(1/(3*np.pi))
print(del_u)
print(el_u)
#print(Std_err[:5])
AP = np.concatenate([del_u,el_u])
print(np.mean(AP))
# Out:
# [ 1.66799947  1.18977122  0.8993825   0.65996633  1.33666251  7.36357401
#   4.30116263  8.99382504  9.80929265 11.86029792]
# [0.96301994 0.68691473 0.51925873 0.38103174 0.77172246 4.25136144
#  2.4832774  5.19258731 5.66339775 6.84754619]
# [0.01121483 0.00621759 0.00367845 0.00221056 0.00386237]
# [0.00471516 0.00249748 0.00441939 0.00439687 0.00487616]
# 0.004808885539777302

# %%
As = np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)])
As2 = np.array([np.mean(A6),np.mean(A7),np.mean(A8),np.mean(A9),np.mean(A10)])
print(As)
print(As2)
# Out:
# [27.33333333 35.16666667 44.93333333 54.86666667 63.6       ]
# [ 95.66666667 105.5        124.66666667 136.66666667 149.        ]

# %%
import numpy as np
A1 = np.array([25,28.8,28.2])
A2 = np.array([35,33.8,36.7])
A3 = np.array([45,43.8,46])
A4 = np.array([55,55.6,54])
A5 = np.array([65,61.8,64])

A6 = np.array([105,95,87])
A7 = np.array([110.5,100,106])
A8 = np.array([136,114,124])
A9 = np.array([149,125,136])
A10 = np.array([164,135,148])

Std = np.array([np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)],np.std(A6),np.std(A7),np.std(A8),np.std(A9),np.std(A10))])
Std_err = Std/np.sqrt(3)
print(Std)
print(Std_err)

del_u = (Std_err[:5]/np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)]))*(1/np.pi)
el_u = (Std_err[-5:]/np.array([np.mean(A6),np.mean(A7),np.mean(A8),np.mean(A9),np.mean(A10)]))*(1/(3*np.pi))
print(del_u)
print(el_u)
#print(Std_err[:5])
AP = np.concatenate([del_u,el_u])
print(np.mean(AP))
# Out:
# [ 1.66799947  1.18977122  0.8993825   0.65996633  1.33666251  7.36357401
#   4.30116263  8.99382504  9.80929265 11.86029792]
# [0.96301994 0.68691473 0.51925873 0.38103174 0.77172246 4.25136144
#  2.4832774  5.19258731 5.66339775 6.84754619]
# [0.01121483 0.00621759 0.00367845 0.00221056 0.00386237]
# [0.00471516 0.00249748 0.00441939 0.00439687 0.00487616]
# 0.004808885539777302

# %%
import numpy as np
A1 = np.array([25,28.8,28.2])
A2 = np.array([35,33.8,36.7])
A3 = np.array([45,43.8,46])
A4 = np.array([55,55.6,54])
A5 = np.array([65,61.8,64])

A6 = np.array([105,95,87])
A7 = np.array([110.5,100,106])
A8 = np.array([136,114,124])
A9 = np.array([149,125,136])
A10 = np.array([164,135,148])

Std = np.array([np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)],np.std(A6),np.std(A7),np.std(A8),np.std(A9),np.std(A10))])
Std_err = Std/np.sqrt(3)
print(Std)
print(Std_err)

del_u = (Std_err[:5]/np.array([np.mean(A1),np.mean(A2),np.mean(A3),np.mean(A4),np.mean(A5)]))*(1/np.pi)
el_u = (Std_err[-5:]/np.array([np.mean(A6),np.mean(A7),np.mean(A8),np.mean(A9),np.mean(A10)]))*(1/(3*np.pi))
print(del_u)
print(el_u)
#print(Std_err[:5])
AP = np.concatenate([del_u,el_u])
print(np.mean(AP))
# Out:
# [ 1.66799947  1.18977122  0.8993825   0.65996633  1.33666251  7.36357401
#   4.30116263  8.99382504  9.80929265 11.86029792]
# [0.96301994 0.68691473 0.51925873 0.38103174 0.77172246 4.25136144
#  2.4832774  5.19258731 5.66339775 6.84754619]
# [0.01121483 0.00621759 0.00367845 0.00221056 0.00386237]
# [0.00471516 0.00249748 0.00441939 0.00439687 0.00487616]
# 0.004808885539777302

# %%
print(np.mean(np.array([0.5123,0.3988,0.3497,0.3220,0.3041,0.5573,0.3876,0.3410,0.3254,0.2881,0.5506,0.4138,0.3567,0.3162,0.2992,0.3230,0.2549,0.2339,0.2131,
0.1996,0.3124,0.2443,0.2152,0.1944,0.1789,0.3031,0.2505,0.2241,0.2034,0.1887])))
# Out:
# 0.3087433333333334

# %%
import numpy as np
ft_km = 0.0003048
Distance = np.array([-3900,27719,46402,60238,59001,66337,36575,12900])
Distance = Distance*ft_km
Height = np.at

# %%
import numpy as np
Height = np.array([-3900,27719,46402,60238,59001,66337,36575,12900])*(0.0003048)
distance = np.array([0,115,214,270,327,407,503,580])
from matplotlib import pyplot as plt

plt.scatter(distance,Height,color = 'red')
plt.plot(distance,Height)
plt.xlabel("Distance (in km)")
plt.ylabel("Height (in km)")
plt.title("Elevation profile of Olympus Mons")
# Out:
# Text(0.5, 1.0, 'Elevation profile of Olympus Mons')

# %% [markdown]
# **Hmm, this is a new write up**

# %%
# NEW CODE
import numpy as np
Ball1_a = np.array([1.53,1.09,1.05,1.24,1.10,1.16,1.07,1.06])
Ball1_b = np.array([1.53,1.18,0.86,1.26,0.97,1.17,1,1.16])
Ball1_c = np.array([1.59,1.10,1.20,1.15,1.04,1.20,0.97,1.20])
Ball1_d = np.array([1.10,0.99,1.08,1.08,1.16,1.10,1.15,1.11])
g = 9.8
rho = 960
Zero_Err = -0.0001

Diameter_1 = 6.23*0.0001 -(Zero_Err)
Mass_1 = 1.0295/1000
#density  =  mass/(4/3pir^3)
sigma_1 = (Mass_1*(6))/(np.pi*Diameter_1**3)
Vt_1 = np.array([0.09237,0.08771,0.09070,0.08850])
# To determine eta we need vt = 2/9(a^2g/eta sigma - rho)
eta_1 = ((2/9)*(((Diameter_1*0.5)**2)*g)/Vt_1)*(sigma_1 - rho)

'''Data - 2 written down'''
Ball2_a = np.array([2.92,1.64,1.73,1.75,1.76,1.72,1.84,1.60])
Ball2_b = np.array([2.57,1.77,1.88,1.54,1.76,1.64,1.81,1.66])
Ball2_c = np.array([1.43,1.77,1.61,1.71,1.68,1.88,1.62,1.62])
Ball2_d = np.array([1.22,1.76,1.69,1.89,1.59,1.66,1.75,1.54])

Diameter_2 = 4.66*0.0001 -(Zero_Err)
Mass_2 = 0.4711/1000
#density  =  mass/(4/3pir^3)
sigma_2 = (Mass_2*(6))/(np.pi*Diameter_2**3)
Vt_2 = np.array([0.05780,0.05822,0.05822,0.06116])
# To determine eta we need vt = 2/9(a^2g/eta sigma - rho)
eta_2 = ((2/9)*(((Diameter_2*0.5)**2)*g)/Vt_2)*(sigma_2 - rho)

'''Data - 3 written down'''
Ball3_a = np.array([1.86,2.26,2.40,2.56,2.02,2.35,2.09,2.17])
Ball3_b = np.array([1.80,2.30,2.31,2.30,2.36,2.22,2.32,2.22])
Ball3_c = np.array([2.36,2.87,3.00,2.83,2.52,2.73,2.45,2.12])
Ball3_d = np.array([1.91,2.39,2.23,2.29,2.37,2.28,2.19,2.22])

Diameter_3 = 3.88*0.0001 -(Zero_Err)
Mass_3 = 0.2588/1000
#density  =  mass/(4/3pir^3)
sigma_3 = (Mass_3*(6))/(np.pi*Diameter_3**3)
Vt_3 = np.array([0.04717,0.04386,0.04073,0.04415])
# To determine eta we need vt = 2/9(a^2g/eta sigma - rho)
eta_3 = ((2/9)*(((Diameter_3*0.5)**2)*g)/Vt_3)*(sigma_3 - rho)

print(eta_1,eta_2,eta_3)

# %%
#Error Propagation
#for this method error would be propagated in way that std_err(eta) = eta*(std_err(terminal velocity)/terminal Velocity)
vt__1a = 0.1/Ball1_a[4:]
vt__1b = 0.1/Ball1_b[4:]
vt__1c = 0.1/Ball1_c[4:]
vt__1d = 0.1/Ball1_d[4:]
vt__2a = 0.1/Ball2_a[4:]
vt__2b = 0.1/Ball2_b[4:]
vt__2c = 0.1/Ball2_c[4:]
vt__2d = 0.1/Ball2_d[4:]
vt__3a = 0.1/Ball3_a[4:]
vt__3b = 0.1/Ball3_b[4:]
vt__3c = 0.1/Ball3_c[4:]
vt__3d = 0.1/Ball3_d[4:]

vt_mean = np.array([np.mean(vt__1a),np.mean(vt__1b),np.mean(vt__1c),np.mean(vt__1d),np.mean(vt__2a),
                   np.mean(vt__2b),np.mean(vt__2c),np.mean(vt__2d),np.mean(vt__3a),np.mean(vt__3b),
                   np.mean(vt__3c),np.mean(vt__3d)])

std_err = np.array([np.std(vt__1a,ddof = 1)/np.sqrt(4),np.std(vt__1b,ddof = 1)/np.sqrt(4),np.std(vt__1c,ddof = 1)/np.sqrt(4),np.std(vt__1d,ddof = 1)/np.sqrt(4),np.std(vt__2a,ddof = 1)/np.sqrt(4),
                   np.std(vt__2b,ddof = 1)/np.sqrt(4),np.std(vt__2c,ddof = 1)/np.sqrt(4),np.std(vt__2d,ddof = 1)/np.sqrt(4),np.std(vt__3a,ddof = 1)/np.sqrt(4),np.std(vt__3b,ddof = 1)/np.sqrt(4),
                   np.std(vt__3c,ddof = 1)/np.sqrt(4),np.std(vt__3d,ddof = 1)/np.sqrt(4)])
print(std_err)
eta = np.concatenate([eta_1,eta_2,eta_3])
eta_err = eta*(std_err/vt_mean)
print(eta_err)

# %%
#Absolute Error
def MER(A):
    return np.mean(np.abs(A - np.mean(A)))

Absolute_err = np.array([MER(vt__1a),MER(vt__1b),MER(vt__1c),MER(vt__1d),MER(vt__2a),MER(vt__2b),
                        MER(vt__2c),MER(vt__2d),MER(vt__3a),MER(vt__3b),MER(vt__3c),MER(vt__3d)])
print(Absolute_err)
